# %%
# Multi Level Classification
    # Predicted value / Level ---> There may be a multiple inserts
    # Photo1 ---> girl / boy   
# Photo features ---> dog/cat/mouse/(More than two classes)
    # Photo2 ---> Cat ---> Multiclass classification
    # Photo3 ---> Cat, Black, Big
    #

# %%
# Score
# Science: , Math: , English:
# Probability english: 95%,  Probability math = 80%
# Threshold value: 0.5 --> 50%
# [1,1,0]

# %%
# StudyHours / EnglishScore / MathScore ---> ZScore --> probability (Sigmoid) --> threshold --> (1,0,1)
