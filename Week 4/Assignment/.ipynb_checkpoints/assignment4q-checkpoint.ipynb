# %%
# Based on your analysis , write at least THREE meaningful business insights suppirted by your visualizations.

# %%
# ---> Based on the analysis of the given dataset, here are four keys business insights that answers the  core operational and strategic questions:

# Most popular course and highest Revenue Course 
    # --> It seems that the Python AI/ML course is the higest demand course ammong all courses,leading enrollment with 100+ students i.e 20% of  total students
# Highest revenue: 
    # --> Python with AI/ML course generates NPR 5,10,000

# Top contributing city
    # --> Janakpur leads the top region for the course enrollmment with volummn of 75 enrollments which generates NPR 3,56,000 in total revenue

# Largest number of students
    # --> Samriddha Pathak  has the largest number of students, instructing 146 students which is 29.2%  of total entrollmentswhich generates NPR 7,01,500 in totalrevenue.

# Students with higher attendance generally achieve higher final scores. 

#  Preferred payment  gateway
    # --> Cash  payment method is the most frequently used method at 27% of transaction are  based on it.  on the other hand  other digital payment methods like eSewa and bank transfers are also  used.
