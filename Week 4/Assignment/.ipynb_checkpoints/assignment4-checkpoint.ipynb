# %%
pip install seaborn

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("dp_lms_student_analytics_dataset.csv")

# %%
df
# Out:
#      StudentID    StudentName  Gender  Age       City             Course  \
# 0            1   Bikash Karki    Male   18    Pokhara     Advanced Excel
# 1            2      Nabin Rai    Male   24     Butwal         MERN Stack
# 2            3   Asmita Thapa  Female   24    Pokhara  Digital Marketing
# 3            4   Nabin Basnet  Female   20    Itahari  Python with AI/ML
# 4            5    Sita Basnet  Female   24   Janakpur     Advanced Excel
# ..         ...            ...     ...  ...        ...                ...
# 495        496  Prakash Karki    Male   30  Kathmandu  Python with AI/ML
# 496        497    Gita Basnet    Male   18    Pokhara              UI/UX
# 497        498      Rohan Rai    Male   24  Kathmandu         MERN Stack
# 498        499   Nabin Basnet    Male   20  Kathmandu              UI/UX
# 499        500    Aarav Karki    Male   28     Butwal     Advanced Excel
#
#            Instructor EnrollmentDate   Batch  CourseFee  ...  \
# ...

# %%
df.columns
# Out:
# Index(['StudentID', 'StudentName', 'Gender', 'Age', 'City', 'Course',
#        'Instructor', 'EnrollmentDate', 'Batch', 'CourseFee', 'PaymentMethod',
#        'AttendancePercentage', 'AssignmentScore', 'QuizScore', 'FinalScore',
#        'CourseProgress', 'StudyHoursPerWeek', 'LoginCount',
#        'CertificateIssued', 'StudentStatus', 'Revenue'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   StudentID             500 non-null    int64
#  1   StudentName           500 non-null    str
#  2   Gender                500 non-null    str
#  3   Age                   500 non-null    int64
#  4   City                  500 non-null    str
#  5   Course                500 non-null    str
#  6   Instructor            500 non-null    str
#  7   EnrollmentDate        500 non-null    str
#  8   Batch                 500 non-null    str
#  9   CourseFee             500 non-null    int64
#  10  PaymentMethod         500 non-null    str
#  11  AttendancePercentage  500 non-null    int64
#  12  AssignmentScore       500 non-null    int64
#  13  QuizScore             500 non-null    int64
#  14  FinalScore            500 non-null    int64
# ...

# %%
df.EnrollmentDate
# Out:
# 0      2025-03-31
# 1      2026-03-09
# 2      2025-10-28
# 3      2026-01-15
# 4      2025-10-02
#           ...
# 495    2025-12-18
# 496    2026-04-28
# 497    2025-06-07
# 498    2025-09-13
# 499    2025-06-21
# Name: EnrollmentDate, Length: 500, dtype: str

# %%
for EnrollmentDate,data in df.groupby("EnrollmentDate"):
    print(EnrollmentDate)
# Out:
# 2025-01-06
# 2025-01-07
# 2025-01-08
# 2025-01-09
# 2025-01-10
# 2025-01-11
# 2025-01-12
# 2025-01-13
# 2025-01-14
# 2025-01-15
# 2025-01-16
# 2025-01-17
# 2025-01-19
# 2025-01-20
# 2025-01-21
# 2025-01-23
# 2025-01-24
# 2025-01-25
# 2025-01-27
# 2025-01-29
# 2025-02-01
# 2025-02-03
# 2025-02-06
# 2025-02-07
# 2025-02-10
# 2025-02-12
# 2025-02-13
# 2025-02-14
# 2025-02-16
# 2025-02-19
# 2025-02-23
# 2025-02-24
# 2025-02-25
# 2025-02-27
# 2025-03-01
# 2025-03-02
# 2025-03-03
# 2025-03-04
# 2025-03-05
# 2025-03-06
# 2025-03-08
# 2025-03-09
# 2025-03-10
# 2025-03-12
# 2025-03-13
# 2025-03-14
# 2025-03-16
# 2025-03-17
# 2025-03-22
# 2025-03-24
# 2025-03-25
# 2025-03-26
# 2025-03-29
# 2025-03-31
# 2025-04-01
# 2025-04-02
# 2025-04-03
# 2025-04-04
# 2025-04-05
# 2025-04-06
# 2025-04-10
# 2025-04-13
# 2025-04-14
# 2025-04-15
# 2025-04-16
# 2025-04-17
# 2025-04-22
# 2025-04-23
# 2025-04-24
# 2025-04-26
# 2025-04-27
# 2025-04-28
# 2025-05-01
# 2025-05-03
# 2025-05-04
# 2025-05-07
# ...

# %%
# 1.⁠ ⁠Line chars
# Create line charts for: 
# Monthly student enrollments 

df['Month'] = df['EnrollmentDate'].str.slice(0, 7)

enrollment_counts = df['Month'].value_counts().sort_index()

plt.figure(figsize= (8, 8))
plt.plot(enrollment_counts.index, enrollment_counts.values, marker='o', color='red')
plt.title('Monthly Student Enrollments')
plt.xlabel('Month')
plt.ylabel('Enrollments')
plt.xticks(rotation=45)
plt.grid(True)

# %%
# Monthly revenue trend 

monthly_revenue = df.groupby('Month')['Revenue'].sum()

plt.figure(figsize=(10, 4))
plt.plot(monthly_revenue.index, monthly_revenue.values, marker='o', color='green')
plt.title('Monthly Revenue Trend')
plt.xlabel('Month')
plt.ylabel('Revenue (NPR)')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.savefig('monthly_revenue_trend.png', dpi=300)

# %%
# Average course progress by month 
# df['Month'] = df['EnrollmentDate'].str.slice(0, 7)

avg_progress = df.groupby('Month')['CourseProgress'].mean()

plt.figure(figsize=(8,6))
plt.plot(avg_progress.index,avg_progress.values,marker ="o", color = "purple")
plt.title("Average course progress by month ")
plt.xlabel("Month")
plt.ylabel("Average progress")
plt.xticks(rotation = 45)
plt.savefig("Average course progress by month.png")
plt.grid(True)

# %%
# Average attendance percentage by month
avg_attendance = df.groupby('Month')["AttendancePercentage"].mean()

plt.plot(avg_attendance.index, avg_attendance.values, marker = "o", color = "red")
plt.title("Average attendance percentage by month")
plt.xlabel("Months")
plt.ylabel("Average attendance percentage")
plt.xticks(rotation = 45)
plt.grid(True)

# %%
df.columns
# Out:
# Index(['StudentID', 'StudentName', 'Gender', 'Age', 'City', 'Course',
#        'Instructor', 'EnrollmentDate', 'Batch', 'CourseFee', 'PaymentMethod',
#        'AttendancePercentage', 'AssignmentScore', 'QuizScore', 'FinalScore',
#        'CourseProgress', 'StudyHoursPerWeek', 'LoginCount',
#        'CertificateIssued', 'StudentStatus', 'Revenue', 'Month'],
#       dtype='str')

# %%
# 2.⁠ ⁠Bar Charts
# Create bar charts showing:

# Number of students in each course
course_count = df.groupby("Course")["Course"].value_counts()
plt.bar(course_count.index, course_count.values)

plt.title("Number of students in each course")
plt.xlabel("Course")
plt.ylabel("Number of students")
plt.xticks(rotation = 45)
plt.grid(axis= "y", linestyle = "--", alpha = 0.8)

# %%
# Revenue generated by each course

revenew_gen = df.groupby("Course")["Revenue"].sum().sort_values(ascending = False)
revenew_gen
plt.bar(revenew_gen.index,revenew_gen.values)

plt.title("Revenue generated by each course")
plt.xlabel("Course")
plt.ylabel("Revenue")
plt.xticks(rotation = 45)
plt.grid(axis= "y", linestyle = "--", alpha = 0.8)

# %%
# Average final score by course

avg_score = df.groupby("Course")["FinalScore"].mean().sort_values(ascending = False)
plt.figure(figsize=(10,8))
plt.bar(avg_score.index,avg_score.values)


plt.title("Average final score by course")
plt.xlabel("Course")
plt.ylabel("Average Final score")
plt.xticks(rotation = 45)
plt.grid(axis= "y", linestyle = "--", alpha = 0.8)

# %%
# Average attendance percentage by course
avg_attendance = df.groupby("Course")["AttendancePercentage"].mean().sort_values(ascending = False)
plt.bar(avg_attendance.index, avg_attendance.values)
plt.title('Average Attendance Percentage by Course', fontsize=14, fontweight='bold')
plt.xlabel('Course')
plt.ylabel('Average Attendance')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %%
# Number of students from each city
city = df.groupby("City")["StudentName"].count()
plt.bar(city.index, city.values)
plt.title('Number of students from each city')
plt.xlabel('City')
plt.ylabel('Number of students')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %%
# Number of students under each instructor
no_instructor = df.groupby("Instructor")["StudentName"].count()

plt.bar(no_instructor.index, no_instructor.values)
plt.title("Number of students under each instructor")
plt.xlabel("Instructor Name")
plt.ylabel("Number of students")
plt.xticks(rotation = 45)
plt.grid(alpha = 0.8, axis = "y", linestyle =  "--")

# %%
# 3.⁠ ⁠Horizontal Bar Charts
# Create horizontal bar charts for:
# Top 10 courses by enrollment

course_counts = df['Course'].value_counts().head(10).sort_values(ascending=True)
# course_counts.index
# course_counts.values

plt.barh(course_counts.index, course_counts.values)
plt.title("Top 10 courses by enrollment")
plt.xlabel("Number of students")
plt.ylabel("Course")
plt.grid(axis='x', linestyle='--', alpha=0.7)

# %%
# Top 10 instructors by student enrollment
std_enrollment = df['Instructor'].value_counts().head(10).sort_values(ascending=True)
# print(std_enrollment)
# std_enrollment.index
# std_enrollment.values

plt.barh(std_enrollment.index,std_enrollment.values)
plt.title("Top 10 instructors by student enrollment")
plt.xlabel("Number of students" )
plt.ylabel("Instructor")
# Out:
# Text(0, 0.5, 'Instructor')

# %%
# Top 10 students with the highest final scores

highest_final_score = df["FinalScore"].value_counts().head(10).sort_values(ascending = True)
# highest_final_score.index
# highest_final_score.values

plt.barh(highest_final_score.index,highest_final_score.values)
plt.title("Top 10 students with the highest final scores")
plt.xlabel("Number of students" )
plt.ylabel("Highest   final score")
plt.grid(axis = "x",linestyle = '--', alpha = 0.7)

# %%
# 4. Histograms
# Create histograms for:
# Course fee

plt.hist(df["CourseFee"])
plt.title('Histogram of Course fee')
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Attendance percentage
plt.hist(df["AttendancePercentage"], edgecolor = "blue", alpha = 0.7)
plt.title('Histogram of Attendance percentage')
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# assignment score
plt.hist(df["AssignmentScore"], edgecolor = "purple", alpha  = 0.7)
plt.title('Histogram of assignment score')
plt.xlabel('Assignment score')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Quiz score

plt.hist(df["QuizScore"], edgecolor = "purple", alpha  = 0.7)
plt.title('Histogram of Quiz Score')
plt.xlabel('Quiz score')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Final score

plt.hist(df["FinalScore"], edgecolor = "purple", alpha  = 0.7)
plt.title('Histogram of Final Score')
plt.xlabel('Final score')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# course progress


plt.hist(df["CourseProgress"], edgecolor = "purple", alpha  = 0.7)
plt.title('Histogram of course progress')
plt.xlabel('course progress')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df["Course"]
# Out:
# 0         Advanced Excel
# 1             MERN Stack
# 2      Digital Marketing
# 3      Python with AI/ML
# 4         Advanced Excel
#              ...
# 495    Python with AI/ML
# 496                UI/UX
# 497           MERN Stack
# 498                UI/UX
# 499       Advanced Excel
# Name: Course, Length: 500, dtype: str

# %%
# 5.⁠ ⁠Pie Charts
# Create pie charts showing:
# Student distribution by course

course_counts = df['Course'].value_counts()
plt.figure(figsize=(8,8))
plt.pie(
    course_counts.values, 
    labels = course_counts.index,
    wedgeprops={'edgecolor': 'white', 'linewidth': 1.5},
    shadow = True,
    startangle= 90
)
plt.title("Student distribution by course")
# Out:
# Text(0.5, 1.0, 'Student distribution by course')

# %%
# Student distribution by gender
# print(df["Gender"])
gender = df.groupby("Gender")["Gender"].count()
gender.index
gender.values
plt.pie(gender.values,labels= gender.index)
plt.title("Student distribution by gender")
# Out:
# Text(0.5, 1.0, 'Student distribution by gender')

# %%
# Payment method distribution
# df["PaymentMethod"]
paymethod = df.groupby("PaymentMethod")["PaymentMethod"].count()
# paymethod.index
# paymethod.values
plt.figure(figsize=(12,6))
plt.pie(paymethod.values, labels = paymethod.index)
plt.title("Payment method distribution")
# Out:
# Text(0.5, 1.0, 'Payment method distribution')

# %%
# Student status distribution

# df["StudentStatus"]
status = df.groupby("StudentStatus")["StudentStatus"].count()
# status.index
# status.values
plt.pie(status.values, labels = status.index)
plt.title("Student status distribution")
# Out:
# Text(0.5, 1.0, 'Student status distribution')

# %%
# Certificate issued vs not issued
# df.columns
certificate  = df.groupby("CertificateIssued")["CertificateIssued"].count()
# certificate.index
# certificate.values
plt.pie(certificate.values, labels = certificate.index)
plt.title("Certificate issued vs not issued")
# Out:
# Text(0.5, 1.0, 'Certificate issued vs not issued')

# %%
# 6.⁠ ⁠Scatter Plots
# Create scatter plots for:
# Attendance Percentage vs Final Score

plt.scatter(df["AttendancePercentage"], df["FinalScore"])
plt.title("Attendance Percentage vs Final Score")
plt.xlabel("Attendance Percentage")
plt.ylabel("Final Score")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# %%
# Assignment Score vs Final Score

plt.scatter(df.AssignmentScore, df.FinalScore)
plt.title("Assignment Score vs Final Score")
plt.xlabel("Assignment Score")
plt.ylabel("Final Score")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# %%
# Quiz score vs final score
plt.scatter(df.QuizScore, df.FinalScore)
plt.title("Quiz Score vs Final Score")
plt.xlabel("Quiz Score")
plt.ylabel("Final Score")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# %%
# Study Hours per Week vs Final Score
plt.scatter(df.StudyHoursPerWeek, df.FinalScore)
plt.title("Study Hours Per Week vs Final Score")
plt.xlabel("Study Hours Per Week")
plt.ylabel("Final Score")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# %%
# Course Progress vs Final Score
plt.scatter(df.CourseProgress, df.FinalScore)
plt.title("Course Progress vs Final Score")
plt.xlabel("Course Progress")
plt.ylabel("Final Score")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# %%
# Attendance Percentage vs Course Progress
plt.scatter(df.AttendancePercentage, df.FinalScore)
plt.title("Attendance Percentage vs Final Score")
plt.xlabel("Attendance Percentage")
plt.ylabel("Final Score")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()

# %%
# 7.⁠ ⁠Chart Formatting
# Every visualization must include
# Appropriate title
# X-axis label
# Y-axis label (where applicable
# Figure size
# Suitable colors
# Grid (where appropriate)
# Proper spacing
# Readable formatting
