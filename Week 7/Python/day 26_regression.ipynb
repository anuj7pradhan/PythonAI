# %%
# pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split #  for training and testing the data

# %%
df = pd.read_csv("datasets/student_marks.csv")

# %%
df
# Out:
#    Student  StudyHours  FinalMarks
# 0    Aarav         1.0          28
# 1   Aayush         2.0          35
# 2     Sita         2.5          40
# 3      Ram         3.0          45
# 4   Anisha         3.5          50
# 5    Rohan         4.0          55
# 6    Priya         4.5          60
# 7    Kiran         5.0          65
# 8    Nabin         5.5          70
# 9    Suman         6.0          74
# 10  Alisha         6.5          79
# 11  Bikash         7.0          84
# 12  Sabina         7.5          88
# 13  Roshan         8.0          92
# 14    Puja         9.0          98

# %%
X = df["StudyHours"]

# %%
X
# Out:
# 0     1.0
# 1     2.0
# 2     2.5
# 3     3.0
# 4     3.5
# 5     4.0
# 6     4.5
# 7     5.0
# 8     5.5
# 9     6.0
# 10    6.5
# 11    7.0
# 12    7.5
# 13    8.0
# 14    9.0
# Name: StudyHours, dtype: float64

# %%
X = df.StudyHours

# %%
X.shape
# Out:
# (15,)

# %%
X.shape
# Out:
# (15,)

# %%
# change it into 2d

# %%
X = df[["StudyHours"]]

# %%
X
# Out:
#     StudyHours
# 0          1.0
# 1          2.0
# 2          2.5
# 3          3.0
# 4          3.5
# 5          4.0
# 6          4.5
# 7          5.0
# 8          5.5
# 9          6.0
# 10         6.5
# 11         7.0
# 12         7.5
# 13         8.0
# 14         9.0

# %%
X.shape
# Out:
# (15, 1)

# %%
Y = df["FinalMarks"]

# %%
Y.shape
# Out:
# (15,)

# %%
# Feature should be in 2d
# label could be in 1d

# %%
# Changing data to numpy array for getting the 
X = X.to_numpy()
Y = Y.to_numpy()

# %%
X
# Out:
# array([[1. ],
#        [2. ],
#        [2.5],
#        [3. ],
#        [3.5],
#        [4. ],
#        [4.5],
#        [5. ],
#        [5.5],
#        [6. ],
#        [6.5],
#        [7. ],
#        [7.5],
#        [8. ],
#        [9. ]])

# %%
Y
# Out:
# array([28, 35, 40, 45, 50, 55, 60, 65, 70, 74, 79, 84, 88, 92, 98])

# %%
# plotting the  data into scatter plot
plt.scatter(X,Y)
plt.xlabel("Study Hours") # providing xlabel
plt.ylabel("Final Marks") # providing ylabel
plt.title("Study Hours vs Final Marks") # providing title to the dataframe
# Out:
# Text(0.5, 1.0, 'Study Hours vs Final Marks')

# %%
# scikit learn

# %%
# Note 
    # Training and testing the data split
    # 80-20 dividion for training and testing

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y)

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2)
    # 0.2 means testing is of testing size
    # costomise it as 70/30 as test_size = 0.3

# %%
# random_state = 42, here 42 is  the optimal outcome so try to use 42

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 42)
model = LinearRegression()
model.fit(X_train, Y_train)
predicted_Y = model.predict(X_test)
comparision = pd.DataFrame({
    "Actual" : Y_test,
    "Predicted" : predicted_Y
})
comparision
# Out:
#    Actual  Predicted
# 0      74  73.227474
# 1      84  82.475628
# 2      28  26.986706

# %%
new_student = np.array([
    [2],
    [4],
    [6],
    [8],
    [10]
])

marks_prediction = model.predict(new_student)
marks_prediction
# Out:
# array([ 36.23485968,  54.73116691,  73.22747415,  91.72378139,
#        110.22008863])
