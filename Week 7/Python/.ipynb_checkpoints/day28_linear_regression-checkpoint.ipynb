# %%
# pip install scikit-learn

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("student_marks.csv")
# df.info()
# df.describe()
# df.isnull().sum()

# Features k ho(input), hamilai chaeyeyo label(output/predicted value) K ho
X = df[["StudyHours"]] #features(input)
Y = df["FinalMarks"] #label

# plt.scatter(X,Y)
# plt.xlabel("Study Hours")
# plt.ylabel("Final Marks")
# plt.title("Study hours vs Final Marks")

# Y.shape
X = X.to_numpy()
Y = Y.to_numpy()

#machine learning
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)
model = LinearRegression()
model.fit(X_train,Y_train)

# predicted_Y = model.predict(X_test)


# comparision = pd.DataFrame({
#     "Actual" : Y_test, 
#     "Predicted" : predicted_Y
# })
# comparision
# # X_test

new_students = np.array([
    [2],
    [4],
    [6],
    [8],
    [22]
])
marks_prediction = model.predict(new_students)
marks_prediction
# Out:
# array([ 36.23485968,  54.73116691,  73.22747415,  91.72378139,
#        221.19793205])

# %%
new_students  = np.array

# %%
# multiple linear regression
# 3 features (study hours, attendance, previousmarks)
# y =  c  + m1x1 + m2x2 +  ... + 
# x1 = study hours,
# x2 = attendance
# x3 = previousmarks

# m1 = study hours impact  on final marks (weight  of x1)
# m2 = attendance impact  on final marks (weight  of x2)
# m3 = previousmarks impact  on final marks (weight  of x3)

# %%
Studyhours = [1,2,3,4,5]
attendancs = [1,2,1,2,1]
marks = [10,15,14,20,18]

# y  = c + m1x1  + m2x2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 Studyhours = [1,2,3,4,5]
#       2 attendancs = [1,2,1,2,1]
#       3 marks = [10,15,14,20,18]
#       4
# ----> 5 y  = c + m1x1  + m2x2
#
# NameError: name 'c' is not defined

# %%
1+2+3+4+5

# %%
15/5

# %%
1+2+1+2+1

# %%
7/5

# %%
10+15+14+20+18

# %%
77/5

# %%
1 - 1.4

# %%
2 -  1.4

# %%
-1 * -  0.4

# %%
2 *  2.6

# %%
1  * 4.6

# %%
0.4 * -5.4

# %%
0.6 * 0.4
