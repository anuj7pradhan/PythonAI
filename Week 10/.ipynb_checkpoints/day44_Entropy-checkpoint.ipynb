# %%
# Decision Tree
# Gini Impurity = Range of 0 - 0.5
# Entropy

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "StudyHours": [1,2,3,4,5],
    "Result": ['fail','fail','fail','pass','pass']
})

# %%
df
# Out:
#    StudyHours Result
# 0           1   fail
# 1           2   fail
# 2           3   fail
# 3           4   pass
# 4           5   pass

# %%
# Entropy = p(fail) log2 (p(fail))) + p(pass) log2 (p(pass)))
# total = 5
# fail = 3
# pass = 2

# Then
    # Entropy = p(fail) log2 (p(fail))) + p(pass) log2 (p(pass)))
    # Entropy = 3/5 log2 (3/5) + 2/5 log2 (2/5)
    # Entropy = 0.971
