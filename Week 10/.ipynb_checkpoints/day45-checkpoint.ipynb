# %%
# lms module
# sms module
# feeatures haru research garnu
# present garnu parcha
# assignment haru gareko jastai
# unique idea haru integrate garunu
# Office busy... sideby part project haruma busy
# sms from japan,nepal, australia
# deadline long abt 1 year

# Edu digitalization
# AI part in Educations system    
#     AI part Vidyro SMS
# DPLMS ---> SMS Module
# Hajirkhata
# pos
# Fragmented
# AI layer haru chaiyo
# Architecture
# base banauna saknu paryo
#

# %%
# db, school name, ph no., is added in super admin
# automation chaiyo
# step 1 > 12 days trial (email notification)
# step 2 > followup mail (do you want to upgrade to premmium plan ??) --> cranjob
# step 3 >
