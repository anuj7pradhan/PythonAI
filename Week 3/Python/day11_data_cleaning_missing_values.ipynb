# %%
import pandas as pd
bdf = pd.read_csv("./Dataset/datasets/bad_daraz_dataset.csv")

# %%
bdf
# Out:
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics    NaN               15     4.6
# 2            3        Shoes      Fashion   3500               5%     4.2
# 3            4      T-Shirt      Fashion   1500               20     NaN
# 4            5        Watch  Accessories   5500               10     4.5
# 5            6   Headphones  Electronics   4200              NaN     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 7            8          Bag      Fashion    abc               12     3.9
# 8            9        Mouse  Electronics   1800                5     4.3
# 9           10     Keyboard  Electronics   2500                5     4.4
# 10          11       Bottle         Home    800                0     5.5
# 11          12        Chair    Furniture  -2500               10     4.0
# ...

# %%
bdf.head()
# Out:
#    product_id product_name     category  price discount_percent  rating  \
# 0           1       Laptop  Electronics  75000               10     4.8
# 1           2        Phone  Electronics    NaN               15     4.6
# 2           3        Shoes      Fashion   3500               5%     4.2
# 3           4      T-Shirt      Fashion   1500               20     NaN
# 4           5        Watch  Accessories   5500               10     4.5
#
#           stock       seller        city    brand gender_target     age  \
# 0            25      TechHub   Kathmandu     Dell        Unisex      25
# 1            40  GadgetNepal     Pokhara  Samsung        Unisex      30
# 2            60   FashionHub     Itahari     Nike          Male      22
# 3           150        Style  Biratnagar   Adidas        Female  Female
# 4  Out of Stock        TimeX   Kathmandu    Casio          Male      28
#
#    reviews
# 0      120
# 1      210
# 2       55
# 3       30
# 4       80

# %%
bdf.isnull()
# Out:
#     product_id  product_name  category  price  discount_percent  rating  \
# 0        False         False     False  False             False   False
# 1        False         False     False   True             False   False
# 2        False         False     False  False             False   False
# 3        False         False     False  False             False    True
# 4        False         False     False  False             False   False
# 5        False         False     False  False              True   False
# 6        False         False     False  False             False   False
# 7        False         False     False  False             False   False
# 8        False         False     False  False             False   False
# 9        False         False     False  False             False   False
# 10       False         False     False  False             False   False
# 11       False         False     False  False             False   False
# ...

# %%
bdf.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'price', 'discount_percent',
#        'rating', 'stock', 'seller', 'city', 'brand', 'gender_target', 'age',
#        'reviews'],
#       dtype='str')

# %%
bdf.shape
# Out:
# (13, 13)

# %%
bdf.isnull().sum()
# Out:
# product_id          0
# product_name        0
# category            0
# price               1
# discount_percent    1
# rating              1
# stock               1
# seller              0
# city                0
# brand               0
# gender_target       0
# age                 1
# reviews             0
# dtype: int64

# %%
# Detect the dirty data
# Missing values (nan,duplicate,wrong dataType, negative Pricing,  etc. )
# Catching outliers
# Inconsistency (kathMANDU,KATHMANDU,kathmandu)
#

# %%
bdf.isnull().sum()
# Out:
# product_id          0
# product_name        0
# category            0
# price               1
# discount_percent    1
# rating              1
# stock               1
# seller              0
# city                0
# brand               0
# gender_target       0
# age                 1
# reviews             0
# dtype: int64

# %%
bdf.fillna(0) # filling na with 0
# Out:
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics      0               15     4.6
# 2            3        Shoes      Fashion   3500               5%     4.2
# 3            4      T-Shirt      Fashion   1500               20     0.0
# 4            5        Watch  Accessories   5500               10     4.5
# 5            6   Headphones  Electronics   4200                0     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 7            8          Bag      Fashion    abc               12     3.9
# 8            9        Mouse  Electronics   1800                5     4.3
# 9           10     Keyboard  Electronics   2500                5     4.4
# 10          11       Bottle         Home    800                0     5.5
# 11          12        Chair    Furniture  -2500               10     4.0
# ...

# %%
# bdf["price"].fillna(bdf["price"].mean())

# %%
dummy = pd.Series(["100","200","300"])
dummy
# Out:
# 0    100
# 1    200
# 2    300
# dtype: str

# %%
pd.to_numeric(dummy)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
dumb = pd.Series(["100","a","300"])
dumb
# Out:
# 0    100
# 1      a
# 2    300
# dtype: str

# %%
# ValueError: Unable to parse string "a" at position 1

# pd.to_numeric(dumb)

# %%
pd.to_numeric(dumb,errors = "coerce")
# Out:
# 0    100.0
# 1      NaN
# 2    300.0
# dtype: float64

# %%
# changing dType of price To numeric and errors  = "coerce" NaN

bdf["price"] = pd.to_numeric(bdf["price"], errors  = "coerce")

bdf
# Out:
#     product_id product_name     category    price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000.0               10     4.8
# 1            2        Phone  Electronics      NaN               15     4.6
# 2            3        Shoes      Fashion   3500.0               5%     4.2
# 3            4      T-Shirt      Fashion   1500.0               20     NaN
# 4            5        Watch  Accessories   5500.0               10     4.5
# 5            6   Headphones  Electronics   4200.0              NaN     4.1
# 6            7       Laptop  Electronics  75000.0               10     4.8
# 7            8          Bag      Fashion      NaN               12     3.9
# 8            9        Mouse  Electronics   1800.0                5     4.3
# 9           10     Keyboard  Electronics   2500.0                5     4.4
# 10          11       Bottle         Home    800.0                0     5.5
# ...

# %%
bdf["price"]=bdf["price"].fillna(bdf["price"].mean())

# %%
bdf
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  14981.818182               15
# 2            3        Shoes      Fashion   3500.000000               5%
# 3            4      T-Shirt      Fashion   1500.000000               20
# 4            5        Watch  Accessories   5500.000000               10
# 5            6   Headphones  Electronics   4200.000000              NaN
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  14981.818182               12
# 8            9        Mouse  Electronics   1800.000000                5
# 9           10     Keyboard  Electronics   2500.000000                5
# 10          11       Bottle         Home    800.000000                0
# 11          12        Chair    Furniture  -2500.000000               10
# ...

# %%
bdf["age"]
# Out:
# 0          25
# 1          30
# 2          22
# 3      Female
# 4          28
# 5         24
# 6          25
# 7          19
# 8         NaN
# 9          21
# 10         26
# 11    Unknown
# 12    Unknown
# Name: age, dtype: str

# %%
bdf["age"] = pd.to_numeric(bdf["age"], errors = "coerce")

# %%
bdf["age"]
# Out:
# 0     25.0
# 1     30.0
# 2     22.0
# 3      NaN
# 4     28.0
# 5     24.0
# 6     25.0
# 7     19.0
# 8      NaN
# 9     21.0
# 10    26.0
# 11     NaN
# 12     NaN
# Name: age, dtype: float64

# %%
bdf
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  14981.818182               15
# 2            3        Shoes      Fashion   3500.000000               5%
# 3            4      T-Shirt      Fashion   1500.000000               20
# 4            5        Watch  Accessories   5500.000000               10
# 5            6   Headphones  Electronics   4200.000000              NaN
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  14981.818182               12
# 8            9        Mouse  Electronics   1800.000000                5
# 9           10     Keyboard  Electronics   2500.000000                5
# 10          11       Bottle         Home    800.000000                0
# 11          12        Chair    Furniture  -2500.000000               10
# ...

# %%
bdf["age"] = bdf["age"].fillna(bdf["age"].median())

# %%
bdf["age"]
# Out:
# 0     25.0
# 1     30.0
# 2     22.0
# 3     25.0
# 4     28.0
# 5     24.0
# 6     25.0
# 7     19.0
# 8     25.0
# 9     21.0
# 10    26.0
# 11    25.0
# 12    25.0
# Name: age, dtype: float64

# %%
bdf
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  14981.818182               15
# 2            3        Shoes      Fashion   3500.000000               5%
# 3            4      T-Shirt      Fashion   1500.000000               20
# 4            5        Watch  Accessories   5500.000000               10
# 5            6   Headphones  Electronics   4200.000000              NaN
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  14981.818182               12
# 8            9        Mouse  Electronics   1800.000000                5
# 9           10     Keyboard  Electronics   2500.000000                5
# 10          11       Bottle         Home    800.000000                0
# 11          12        Chair    Furniture  -2500.000000               10
# ...

# %%
bdf.dropna()

bdf[bdf.duplicated()]
# Out:
#     product_id product_name   category   price discount_percent  rating stock  \
# 12          12        Chair  Furniture -2500.0               10     4.0    -5
#
#      seller      city brand gender_target   age  reviews
# 12  FurniCo  Lalitpur  IKEA        Unisex  25.0       44

# %%
bdf
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  14981.818182               15
# 2            3        Shoes      Fashion   3500.000000               5%
# 3            4      T-Shirt      Fashion   1500.000000               20
# 4            5        Watch  Accessories   5500.000000               10
# 5            6   Headphones  Electronics   4200.000000              NaN
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  14981.818182               12
# 8            9        Mouse  Electronics   1800.000000                5
# 9           10     Keyboard  Electronics   2500.000000                5
# 10          11       Bottle         Home    800.000000                0
# 11          12        Chair    Furniture  -2500.000000               10
# ...

# %%
bdf.dropna()
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  14981.818182               15
# 2            3        Shoes      Fashion   3500.000000               5%
# 4            5        Watch  Accessories   5500.000000               10
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  14981.818182               12
# 9           10     Keyboard  Electronics   2500.000000                5
# 10          11       Bottle         Home    800.000000                0
# 11          12        Chair    Furniture  -2500.000000               10
# 12          12        Chair    Furniture  -2500.000000               10
#
#     rating         stock       seller         city      brand gender_target  \
# 0      4.8            25      TechHub    Kathmandu       Dell        Unisex
# ...

# %%
bdf.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# dtype: bool

# %%
bdf[bdf.duplicated()]
# Out:
#     product_id product_name   category   price discount_percent  rating stock  \
# 12          12        Chair  Furniture -2500.0               10     4.0    -5
#
#      seller      city brand gender_target   age  reviews
# 12  FurniCo  Lalitpur  IKEA        Unisex  25.0       44

# %%
bdf.discount_percent
# Out:
# 0      10
# 1      15
# 2      5%
# 3      20
# 4      10
# 5     NaN
# 6      10
# 7      12
# 8       5
# 9       5
# 10      0
# 11     10
# 12     10
# Name: discount_percent, dtype: str

# %%
bdf["discount_percent"] = bdf["discount_percent"].str.replace("%","")

# %%
bdf.discount_percent
# Out:
# 0      10
# 1      15
# 2       5
# 3      20
# 4      10
# 5     NaN
# 6      10
# 7      12
# 8       5
# 9       5
# 10      0
# 11     10
# 12     10
# Name: discount_percent, dtype: str

# %%
bdf["discount_percentage"] = bdf["discount_percent"].str.replace("%","")
bdf
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  14981.818182               15
# 2            3        Shoes      Fashion   3500.000000                5
# 3            4      T-Shirt      Fashion   1500.000000               20
# 4            5        Watch  Accessories   5500.000000               10
# 5            6   Headphones  Electronics   4200.000000              NaN
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  14981.818182               12
# 8            9        Mouse  Electronics   1800.000000                5
# 9           10     Keyboard  Electronics   2500.000000                5
# 10          11       Bottle         Home    800.000000                0
# 11          12        Chair    Furniture  -2500.000000               10
# ...

# %%
bdf.fillna(0) # filling na with 0
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  14981.818182               15
# 2            3        Shoes      Fashion   3500.000000                5
# 3            4      T-Shirt      Fashion   1500.000000               20
# 4            5        Watch  Accessories   5500.000000               10
# 5            6   Headphones  Electronics   4200.000000                0
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  14981.818182               12
# 8            9        Mouse  Electronics   1800.000000                5
# 9           10     Keyboard  Electronics   2500.000000                5
# 10          11       Bottle         Home    800.000000                0
# 11          12        Chair    Furniture  -2500.000000               10
# ...

# %%
bdf[bdf.duplicated()]
# Out:
#     product_id product_name   category   price discount_percent  rating stock  \
# 12          12        Chair  Furniture -2500.0               10     4.0    -5
#
#      seller      city brand gender_target   age  reviews discount_percentage
# 12  FurniCo  Lalitpur  IKEA        Unisex  25.0       44                  10

# %%
bdf.drop_duplicates(inplace=True)

# %%
bdf
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  14981.818182               15
# 2            3        Shoes      Fashion   3500.000000                5
# 3            4      T-Shirt      Fashion   1500.000000               20
# 4            5        Watch  Accessories   5500.000000               10
# 5            6   Headphones  Electronics   4200.000000              NaN
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  14981.818182               12
# 8            9        Mouse  Electronics   1800.000000                5
# 9           10     Keyboard  Electronics   2500.000000                5
# 10          11       Bottle         Home    800.000000                0
# 11          12        Chair    Furniture  -2500.000000               10
#
# ...

# %%
bdf.fillna(0) # filling na with 0
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  14981.818182               15
# 2            3        Shoes      Fashion   3500.000000                5
# 3            4      T-Shirt      Fashion   1500.000000               20
# 4            5        Watch  Accessories   5500.000000               10
# 5            6   Headphones  Electronics   4200.000000                0
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  14981.818182               12
# 8            9        Mouse  Electronics   1800.000000                5
# 9           10     Keyboard  Electronics   2500.000000                5
# 10          11       Bottle         Home    800.000000                0
# 11          12        Chair    Furniture  -2500.000000               10
#
# ...
