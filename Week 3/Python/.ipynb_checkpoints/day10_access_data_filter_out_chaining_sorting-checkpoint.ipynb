# %%
# pandas introduction

# Read operations dataset
# Basic dataset review(sample,head,tail,describe,info etc.)
# daraz/ecommerce platform dataset
# Filtering, Sorting, Cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv("./Dataset/datasets/daraz_dataset.csv")

# %%
print(df)
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender   District  \
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male  Nepalgunj
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female    Pokhara
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female   Lalitpur
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male    Chitwan
# 4    DZ100005  2026-03-16    Ram Adhikari   32    Male     Dharan
# ..        ...         ...             ...  ...     ...        ...
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male  Nepalgunj
# 496  DZ100497  2026-05-10    Ram Adhikari   35  Female  Bhaktapur
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female    Itahari
# 498  DZ100499  2026-01-22   Gita Shrestha   27  Female     Dharan
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male  Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 0         Sports           Football         1      48898               10
# ...

# %%
df.columns # Shows how many columns are ther in the dataset
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerName', 'Age', 'Gender', 'District',
#        'Category', 'Product', 'Quantity', 'UnitPrice', 'DiscountPercent',
#        'TotalAmount', 'PaymentMethod', 'Rating', 'OrderStatus'],
#       dtype='str')

# %%
df.head() # returns first 5 rows of the dataset
# Out:
#     OrderID   OrderDate  CustomerName  Age  Gender   District     Category  \
# 0  DZ100001  2026-03-04  Anita Basnet   24    Male  Nepalgunj       Sports
# 1  DZ100002  2026-01-07  Pooja Basnet   52  Female    Pokhara  Electronics
# 2  DZ100003  2026-03-29  Rohit Basnet   31  Female   Lalitpur        Books
# 3  DZ100004  2026-04-28  Pooja Sharma   42    Male    Chitwan         Home
# 4  DZ100005  2026-03-16  Ram Adhikari   32    Male     Dharan    Groceries
#
#              Product  Quantity  UnitPrice  DiscountPercent  TotalAmount  \
# 0           Football         1      48898               10     44008.20
# 1  Bluetooth Speaker         2      33418               20     53468.80
# 2      Python Basics         2      46053               15     78290.10
# 3              Chair         5      17635                0     88175.00
# 4                Tea         1       3303                5      3137.85
#
#   PaymentMethod  Rating OrderStatus
# 0       IME Pay       1   Delivered
# ...

# %%
df.describe() # describes the dataset
# Out:
#               Age    Quantity     UnitPrice  DiscountPercent    TotalAmount  \
# count  500.000000  500.000000    500.000000       500.000000     500.000000
# mean    36.114000    3.116000  25433.808000        10.630000   70063.721000
# std     10.969853    1.424993  14012.030302         7.304781   52519.872403
# min     18.000000    1.000000    468.000000         0.000000     478.800000
# 25%     27.000000    2.000000  12581.000000         5.000000   27237.225000
# 50%     36.000000    3.000000  26243.500000        10.000000   55536.500000
# 75%     46.000000    4.000000  37552.000000        16.250000  106513.650000
# max     55.000000    5.000000  49958.000000        20.000000  229910.000000
#
#            Rating
# count  500.000000
# mean     2.990000
# std      1.393479
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max      5.000000

# %%
df.info() #Provides all the informations of the dataset
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          500 non-null    str
#  1   OrderDate        500 non-null    str
#  2   CustomerName     500 non-null    str
#  3   Age              500 non-null    int64
#  4   Gender           500 non-null    str
#  5   District         500 non-null    str
#  6   Category         500 non-null    str
#  7   Product          500 non-null    str
#  8   Quantity         500 non-null    int64
#  9   UnitPrice        500 non-null    int64
#  10  DiscountPercent  500 non-null    int64
#  11  TotalAmount      500 non-null    float64
#  12  PaymentMethod    500 non-null    str
#  13  Rating           500 non-null    int64
#  14  OrderStatus      500 non-null    str
# dtypes: float64(1), int64(5), str(9)
# memory usage: 58.7 KB

# %%
df.Age
# Out:
# 0      24
# 1      52
# 2      31
# 3      42
# 4      32
#        ..
# 495    48
# 496    35
# 497    27
# 498    27
# 499    25
# Name: Age, Length: 500, dtype: int64

# %%
print(df.Age[20])
print(df.Age[24])
# Out:
# 52
# 33

# %%
print(df.TotalAmount) # returns all the TotalAmount
# Out:
# 0       44008.20
# 1       53468.80
# 2       78290.10
# 3       88175.00
# 4        3137.85
#          ...
# 495    115060.80
# 496     21686.60
# 497     48890.00
# 498     11106.00
# 499     68693.40
# Name: TotalAmount, Length: 500, dtype: float64

# %%
print(df.TotalAmount.max()) # Max amount from dataset
# Out:
# 229910.0

# %%
print(df.TotalAmount.min())
# Out:
# 478.8

# %%
print(df.CustomerName)
# Out:
# 0        Anita Basnet
# 1        Pooja Basnet
# 2        Rohit Basnet
# 3        Pooja Sharma
# 4        Ram Adhikari
#             ...
# 495        Sita Thapa
# 496      Ram Adhikari
# 497    Nabin Shrestha
# 498     Gita Shrestha
# 499    Rohit Adhikari
# Name: CustomerName, Length: 500, dtype: str

# %%
print(df.TotalAmount.mean())
# Out:
# 70063.721

# %%
print(df.CustomerName,df.District)
# Out:
# 0        Anita Basnet
# 1        Pooja Basnet
# 2        Rohit Basnet
# 3        Pooja Sharma
# 4        Ram Adhikari
#             ...
# 495        Sita Thapa
# 496      Ram Adhikari
# 497    Nabin Shrestha
# 498     Gita Shrestha
# 499    Rohit Adhikari
# Name: CustomerName, Length: 500, dtype: str 0      Nepalgunj
# 1        Pokhara
# 2       Lalitpur
# 3        Chitwan
# 4         Dharan
#          ...
# 495    Nepalgunj
# 496    Bhaktapur
# 497      Itahari
# 498       Dharan
# 499    Bhaktapur
# Name: District, Length: 500, dtype: str

# %%
# provides in list
print(df[["CustomerName","District"]])
# Out:
#        CustomerName   District
# 0      Anita Basnet  Nepalgunj
# 1      Pooja Basnet    Pokhara
# 2      Rohit Basnet   Lalitpur
# 3      Pooja Sharma    Chitwan
# 4      Ram Adhikari     Dharan
# ..              ...        ...
# 495      Sita Thapa  Nepalgunj
# 496    Ram Adhikari  Bhaktapur
# 497  Nabin Shrestha    Itahari
# 498   Gita Shrestha     Dharan
# 499  Rohit Adhikari  Bhaktapur
#
# [500 rows x 2 columns]

# %%
print(df[["CustomerName","District","TotalAmount"]])
# Out:
#        CustomerName   District  TotalAmount
# 0      Anita Basnet  Nepalgunj     44008.20
# 1      Pooja Basnet    Pokhara     53468.80
# 2      Rohit Basnet   Lalitpur     78290.10
# 3      Pooja Sharma    Chitwan     88175.00
# 4      Ram Adhikari     Dharan      3137.85
# ..              ...        ...          ...
# 495      Sita Thapa  Nepalgunj    115060.80
# 496    Ram Adhikari  Bhaktapur     21686.60
# 497  Nabin Shrestha    Itahari     48890.00
# 498   Gita Shrestha     Dharan     11106.00
# 499  Rohit Adhikari  Bhaktapur     68693.40
#
# [500 rows x 3 columns]

# %%
# iloc() method - integer location
print(df.iloc[1])
# Out:
# OrderID                     DZ100002
# OrderDate                 2026-01-07
# CustomerName            Pooja Basnet
# Age                               52
# Gender                        Female
# District                     Pokhara
# Category                 Electronics
# Product            Bluetooth Speaker
# Quantity                           2
# UnitPrice                      33418
# DiscountPercent                   20
# TotalAmount                  53468.8
# PaymentMethod                IME Pay
# Rating                             5
# OrderStatus                Cancelled
# Name: 1, dtype: object

# %%
print(df.iloc[1,2]) # Column vaues, index 1 ko 2nd column ko value print garcha
df.head(2) # first 2 rows
# Out:
# Pooja Basnet
#     OrderID   OrderDate  CustomerName  Age  Gender   District     Category  \
# 0  DZ100001  2026-03-04  Anita Basnet   24    Male  Nepalgunj       Sports
# 1  DZ100002  2026-01-07  Pooja Basnet   52  Female    Pokhara  Electronics
#
#              Product  Quantity  UnitPrice  DiscountPercent  TotalAmount  \
# 0           Football         1      48898               10      44008.2
# 1  Bluetooth Speaker         2      33418               20      53468.8
#
#   PaymentMethod  Rating OrderStatus
# 0       IME Pay       1   Delivered
# 1       IME Pay       5   Cancelled

# %%
print(df.iloc[0])
# Out:
# OrderID                DZ100001
# OrderDate            2026-03-04
# CustomerName       Anita Basnet
# Age                          24
# Gender                     Male
# District              Nepalgunj
# Category                 Sports
# Product                Football
# Quantity                      1
# UnitPrice                 48898
# DiscountPercent              10
# TotalAmount             44008.2
# PaymentMethod           IME Pay
# Rating                        1
# OrderStatus           Delivered
# Name: 0, dtype: object

# %%
print(df.iloc[0:6]) # Number of row tancha
# Out:
#     OrderID   OrderDate  CustomerName  Age  Gender   District     Category  \
# 0  DZ100001  2026-03-04  Anita Basnet   24    Male  Nepalgunj       Sports
# 1  DZ100002  2026-01-07  Pooja Basnet   52  Female    Pokhara  Electronics
# 2  DZ100003  2026-03-29  Rohit Basnet   31  Female   Lalitpur        Books
# 3  DZ100004  2026-04-28  Pooja Sharma   42    Male    Chitwan         Home
# 4  DZ100005  2026-03-16  Ram Adhikari   32    Male     Dharan    Groceries
# 5  DZ100006  2026-06-29  Ram Shrestha   28    Male  Bhaktapur      Fashion
#
#              Product  Quantity  UnitPrice  DiscountPercent  TotalAmount  \
# 0           Football         1      48898               10     44008.20
# 1  Bluetooth Speaker         2      33418               20     53468.80
# 2      Python Basics         2      46053               15     78290.10
# 3              Chair         5      17635                0     88175.00
# 4                Tea         1       3303                5      3137.85
# ...

# %%
print(df.iloc[0,2])
# Out:
# Anita Basnet

# %%
print(df.iloc[0,7])
# Out:
# Football

# %%
df.head()
# Out:
#     OrderID   OrderDate  CustomerName  Age  Gender   District     Category  \
# 0  DZ100001  2026-03-04  Anita Basnet   24    Male  Nepalgunj       Sports
# 1  DZ100002  2026-01-07  Pooja Basnet   52  Female    Pokhara  Electronics
# 2  DZ100003  2026-03-29  Rohit Basnet   31  Female   Lalitpur        Books
# 3  DZ100004  2026-04-28  Pooja Sharma   42    Male    Chitwan         Home
# 4  DZ100005  2026-03-16  Ram Adhikari   32    Male     Dharan    Groceries
#
#              Product  Quantity  UnitPrice  DiscountPercent  TotalAmount  \
# 0           Football         1      48898               10     44008.20
# 1  Bluetooth Speaker         2      33418               20     53468.80
# 2      Python Basics         2      46053               15     78290.10
# 3              Chair         5      17635                0     88175.00
# 4                Tea         1       3303                5      3137.85
#
#   PaymentMethod  Rating OrderStatus
# 0       IME Pay       1   Delivered
# ...

# %%
print(df.iloc[:])
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender   District  \
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male  Nepalgunj
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female    Pokhara
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female   Lalitpur
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male    Chitwan
# 4    DZ100005  2026-03-16    Ram Adhikari   32    Male     Dharan
# ..        ...         ...             ...  ...     ...        ...
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male  Nepalgunj
# 496  DZ100497  2026-05-10    Ram Adhikari   35  Female  Bhaktapur
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female    Itahari
# 498  DZ100499  2026-01-22   Gita Shrestha   27  Female     Dharan
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male  Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 0         Sports           Football         1      48898               10
# ...

# %%
print(df.iloc[:,2])
# Out:
# 0        Anita Basnet
# 1        Pooja Basnet
# 2        Rohit Basnet
# 3        Pooja Sharma
# 4        Ram Adhikari
#             ...
# 495        Sita Thapa
# 496      Ram Adhikari
# 497    Nabin Shrestha
# 498     Gita Shrestha
# 499    Rohit Adhikari
# Name: CustomerName, Length: 500, dtype: str

# %%
print(df.iloc[:,[2,4,5]])
# Out:
#        CustomerName  Gender   District
# 0      Anita Basnet    Male  Nepalgunj
# 1      Pooja Basnet  Female    Pokhara
# 2      Rohit Basnet  Female   Lalitpur
# 3      Pooja Sharma    Male    Chitwan
# 4      Ram Adhikari    Male     Dharan
# ..              ...     ...        ...
# 495      Sita Thapa    Male  Nepalgunj
# 496    Ram Adhikari  Female  Bhaktapur
# 497  Nabin Shrestha  Female    Itahari
# 498   Gita Shrestha  Female     Dharan
# 499  Rohit Adhikari    Male  Bhaktapur
#
# [500 rows x 3 columns]

# %%
print(df.iloc[0:2,0:3])
# Out:
#     OrderID   OrderDate  CustomerName
# 0  DZ100001  2026-03-04  Anita Basnet
# 1  DZ100002  2026-01-07  Pooja Basnet

# %%
# loc ---> location, name / label

# %%
print(df.loc[0])
# Out:
# OrderID                DZ100001
# OrderDate            2026-03-04
# CustomerName       Anita Basnet
# Age                          24
# Gender                     Male
# District              Nepalgunj
# Category                 Sports
# Product                Football
# Quantity                      1
# UnitPrice                 48898
# DiscountPercent              10
# TotalAmount             44008.2
# PaymentMethod           IME Pay
# Rating                        1
# OrderStatus           Delivered
# Name: 0, dtype: object

# %%
print(df.loc[:,"CustomerName"])
# Out:
# 0        Anita Basnet
# 1        Pooja Basnet
# 2        Rohit Basnet
# 3        Pooja Sharma
# 4        Ram Adhikari
#             ...
# 495        Sita Thapa
# 496      Ram Adhikari
# 497    Nabin Shrestha
# 498     Gita Shrestha
# 499    Rohit Adhikari
# Name: CustomerName, Length: 500, dtype: str

# %%
print(df.loc[df["District"] =="Kathmandu"])
# Out:
#       OrderID   OrderDate      CustomerName  Age  Gender   District  \
# 28   DZ100029  2026-05-30      Pooja Basnet   45    Male  Kathmandu
# 30   DZ100031  2026-03-10    Nabin Adhikari   24  Female  Kathmandu
# 39   DZ100040  2026-01-28     Manish Basnet   29  Female  Kathmandu
# 63   DZ100064  2026-04-15      Sabina Thapa   48  Female  Kathmandu
# 104  DZ100105  2026-02-10         Kiran Rai   38    Male  Kathmandu
# 109  DZ100110  2026-04-14        Manish Rai   25  Female  Kathmandu
# 127  DZ100128  2026-06-30       Suman Karki   18    Male  Kathmandu
# 133  DZ100134  2026-01-10      Sneha Basnet   20    Male  Kathmandu
# 147  DZ100148  2026-02-09       Nabin Thapa   39    Male  Kathmandu
# 160  DZ100161  2026-01-09      Roshan Thapa   25    Male  Kathmandu
# 175  DZ100176  2026-06-30      Kiran Sharma   54    Male  Kathmandu
# 177  DZ100178  2026-05-25     Sita Shrestha   47  Female  Kathmandu
# 181  DZ100182  2026-03-30          Gita Rai   30    Male  Kathmandu
# ...

# %%
ktm = df.loc[df["District"] == "Kathmandu"]
ktm
# Out:
#       OrderID   OrderDate      CustomerName  Age  Gender   District  \
# 28   DZ100029  2026-05-30      Pooja Basnet   45    Male  Kathmandu
Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 1    Electronics  Bluetooth Speaker         2      33418               20
# ...

# %%
df[(df.District == "Kathmandu")&(df.PaymentMethod == "eSewa")&(df.Gender == "Male")]
# Out:
#       OrderID   OrderDate   CustomerName  Age Gender   District     Category  \
# 147  DZ100148  2026-02-09    Nabin Thapa   39   Male  Kathmandu  Electronics
# 193  DZ100194  2026-06-14  Sita Shrestha   20   Male  Kathmandu      Fashion
#
#          Product  Quantity  UnitPrice  DiscountPercent  TotalAmount  \
# 147  Smart Watch         2      39084               20      62534.4
# 193       Jacket         4      12361               20      39555.2
#
#     PaymentMethod  Rating OrderStatus
# 147         eSewa       1  Processing
# 193         eSewa       4     Shipped

# %%
df[(df.District == "Kathmandu")&(df.PaymentMethod == "eSewa")&(df.Gender == "Female")]
# Out:
#       OrderID   OrderDate   CustomerName  Age  Gender   District   Category  \
# 234  DZ100235  2026-05-28  Gita Shrestha   49  Female  Kathmandu       Home
# 269  DZ100270  2026-05-07      Pooja Rai   29  Female  Kathmandu  Groceries
# 460  DZ100461  2026-05-27   Pooja Basnet   47  Female  Kathmandu    Fashion
#
#       Product  Quantity  UnitPrice  DiscountPercent  TotalAmount  \
# 234     Chair         3      22435               20      53844.0
# 269  Biscuits         2      37203                5      70685.7
# 460  Sneakers         3      40348               20      96835.2
#
#     PaymentMethod  Rating OrderStatus
# 234         eSewa       1    Returned
# 269         eSewa       1     Shipped
# 460         eSewa       3   Cancelled

# %%
df[(df["PaymentMethod"] == "eSewa") & (df["District"] == "Kathmandu")]
# Out:
#       OrderID   OrderDate   CustomerName  Age  Gender   District     Category  \
# 147  DZ100148  2026-02-09    Nabin Thapa   39    Male  Kathmandu  Electronics
# 193  DZ100194  2026-06-14  Sita Shrestha   20    Male  Kathmandu      Fashion
# 234  DZ100235  2026-05-28  Gita Shrestha   49  Female  Kathmandu         Home
# 269  DZ100270  2026-05-07      Pooja Rai   29  Female  Kathmandu    Groceries
# 460  DZ100461  2026-05-27   Pooja Basnet   47  Female  Kathmandu      Fashion
#
#          Product  Quantity  UnitPrice  DiscountPercent  TotalAmount  \
# 147  Smart Watch         2      39084               20      62534.4
# 193       Jacket         4      12361               20      39555.2
# 234        Chair         3      22435               20      53844.0
# 269     Biscuits         2      37203                5      70685.7
# 460     Sneakers         3      40348               20      96835.2
#
#     PaymentMethod  Rating OrderStatus
# 147         eSewa       1  Processing
# ...

# %%
df[(df["Category"] == "Electronics") & (df["Rating"] == 5)]
# Out:
#       OrderID   OrderDate     CustomerName  Age  Gender    District  \
# 1    DZ100002  2026-01-07     Pooja Basnet   52  Female     Pokhara
# 57   DZ100058  2026-06-26     Nabin Basnet   31  Female  Biratnagar
# 97   DZ100098  2026-02-02   Rohit Shrestha   55  Female      Dharan
# 180  DZ100181  2026-02-02   Anita Adhikari   18    Male  Biratnagar
# 205  DZ100206  2026-05-23     Ramesh Karki   24    Male    Lalitpur
# 271  DZ100272  2026-01-29  Ramesh Adhikari   41    Male     Itahari
# 280  DZ100281  2026-02-09         Sita Rai   18  Female    Lalitpur
# 324  DZ100325  2026-05-08     Aarav Sharma   43  Female   Kathmandu
# 329  DZ100330  2026-05-10       Gita Karki   18    Male     Chitwan
# 355  DZ100356  2026-02-05     Pooja Basnet   34    Male    Lalitpur
# 377  DZ100378  2026-02-21       Ramesh Rai   30    Male   Nepalgunj
# 387  DZ100388  2026-01-09       Ramesh Rai   43    Male      Butwal
# 395  DZ100396  2026-06-11    Gita Adhikari   28  Female      Dharan
# ...
