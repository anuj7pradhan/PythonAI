# %%
import pandas as pd
bdf = pd.read_csv("./Dataset/datasets/bad_daraz_dataset.csv")

# %%
bdf
# Out:
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics    NaN               15     4.6
# 2            3        Shoes      Fashion   3500               5%     4.2
# 3            4      T-Shirt      Fashion   1500               20     NaN
# 4            5        Watch  Accessories   5500               10     4.5
# 5            6   Headphones  Electronics   4200              NaN     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 7            8          Bag      Fashion    abc               12     3.9
# 8            9        Mouse  Electronics   1800                5     4.3
# 9           10     Keyboard  Electronics   2500                5     4.4
# 10          11       Bottle         Home    800                0     5.5
# 11          12        Chair    Furniture  -2500               10     4.0
#
# ...

# %%
bdf.head()
# Out:
#    product_id product_name     category  price discount_percent  rating  \
# 0           1       Laptop  Electronics  75000               10     4.8
# 1           2        Phone  Electronics    NaN               15     4.6
# 2           3        Shoes      Fashion   3500               5%     4.2
# 3           4      T-Shirt      Fashion   1500               20     NaN
# 4           5        Watch  Accessories   5500               10     4.5
#
#           stock       seller        city    brand gender_target     age  \
# 0            25      TechHub   Kathmandu     Dell        Unisex      25
# 1            40  GadgetNepal     Pokhara  Samsung        Unisex      30
# 2            60   FashionHub     Itahari     Nike          Male      22
# 3           150        Style  Biratnagar   Adidas        Female  Female
# 4  Out of Stock        TimeX   Kathmandu    Casio          Male      28
#
#    reviews
# 0      120
# 1      210
# 2       55
# 3       30
# 4       80

# %%
bdf.isnull()
# Out:
#     product_id  product_name  category  price  discount_percent  rating  \
# 0        False         False     False  False             False   False
# 1        False         False     False   True             False   False
# 2        False         False     False  False             False   False
# 3        False         False     False  False             False    True
# 4        False         False     False  False             False   False
# 5        False         False     False  False              True   False
# 6        False         False     False  False             False   False
# 7        False         False     False  False             False   False
# 8        False         False     False  False             False   False
# 9        False         False     False  False             False   False
# 10       False         False     False  False             False   False
# 11       False         False     False  False             False   False
#
# ...

# %%
bdf.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'price', 'discount_percent',
#        'rating', 'stock', 'seller', 'city', 'brand', 'gender_target', 'age',
#        'reviews'],
#       dtype='str')

# %%
bdf.shape
# Out:
# (12, 13)

# %%
bdf.isnull().sum()
# Out:
# product_id          0
# product_name        0
# category            0
# price               1
# discount_percent    1
# rating              1
# stock               1
# seller              0
# city                0
# brand               0
# gender_target       0
# age                 1
# reviews             0
# dtype: int64

# %%
# Detect the dirty data
# Missing values (nan,duplicate,wrong dataType, negative Pricing,  etc. )
# Catching outliers
# Inconsistency (kathMANDU,KATHMANDU,kathmandu)
#

# %%
bdf.isnull().sum()
# Out:
# product_id          0
# product_name        0
# category            0
# price               1
# discount_percent    1
# rating              1
# stock               1
# seller              0
# city                0
# brand               0
# gender_target       0
# age                 1
# reviews             0
# dtype: int64
