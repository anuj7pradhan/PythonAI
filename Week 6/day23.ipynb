# %%
import pandas as pd
import numpy as np
# Scalar

x = 10
y = 20
# x and y has a single value and is called scalar.

age = 29
roll_no = 2

# age and roroll_no has a single value and is called scalar.

# %%
age  = [20]

# %%
# Vector

# A collection of scalar is called a vector
# eg.
# age = np.array([1, 2, 3, 4, 5])
    # Note: list of scalar values is called vector.

# %%
ages = [20,30,40,38,33]
age_vector = pd.Series(ages)

# %%
age_vector
# Out:
# 0    20
# 1    30
# 2    40
# 3    38
# 4    33
# dtype: int64

# %%
pd.DataFrame(age_vector)
# Out:
#     0
# 0  20
# 1  30
# 2  40
# 3  38
# 4  33

# %%
df = pd.read_csv("daraz_dataset.csv")

# %%
df.head()
# Out:
#     OrderID   OrderDate  CustomerName  Age  Gender   District     Category  \
# 0  DZ100001  2026-03-04  Anita Basnet   24    Male  Nepalgunj       Sports
# 1  DZ100002  2026-01-07  Pooja Basnet   52  Female    Pokhara  Electronics
# 2  DZ100003  2026-03-29  Rohit Basnet   31  Female   Lalitpur        Books
# 3  DZ100004  2026-04-28  Pooja Sharma   42    Male    Chitwan         Home
# 4  DZ100005  2026-03-16  Ram Adhikari   32    Male     Dharan    Groceries
#
#              Product  Quantity  UnitPrice  DiscountPercent  TotalAmount  \
# 0           Football         1      48898               10     44008.20
# 1  Bluetooth Speaker         2      33418               20     53468.80
# 2      Python Basics         2      46053               15     78290.10
# 3              Chair         5      17635                0     88175.00
# 4                Tea         1       3303                5      3137.85
#
#   PaymentMethod  Rating OrderStatus
# 0       IME Pay       1   Delivered
# ...

# %%
# in mathematics it is called vector
age = np.array([10,20,30,40])
print(age)

roll_no = np.array([20,21,22,23])
print(roll_no)

# we got 2 vector from above data
# i.e 
# [10 20 30 40]
# [20 21 22 23]
# Out:
# [10 20 30 40]
# [20 21 22 23]

# %%
# vector + vector chahi matrix   huncha

# ie.
vdf = np.array([
    [1,2,3],
    [4,5,6]
])
print(vdf)
# it is a matrix, a collection of vectors
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
vdf.transpose()
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
st_data = np.array([12,90])
weight = np.array([10,2])

prediction = np.dot(st_data, weight)
prediction
# Out:
# np.int64(300)

# %%
st_data = np.array([12,90,18,200,30])
weight = np.array([10,2,2,4,3])
prediction = np.dot(st_data, weight)
prediction
# Out:
# np.int64(1226)

# %%
st_data = np.array([
    [12,90,18,200,30],
    [1,2,3,4,5],
    [23,23,43,3,43]
])
s_hrs = np.array([
    [10,2,2,4,3],
    [1,2,3,4,5],
    [5,4,3,2,1]
])

weight = np.array([
    [10],
    [2],
    [3],
    [34],
    [3]
])
print(st_data)

prediction = np.dot(st_data, weight)
print(prediction)
# Out:
# [[ 12  90  18 200  30]
#  [  1   2   3   4   5]
#  [ 23  23  43   3  43]]
# [[7244]
#  [ 174]
#  [ 636]]

# %%
a = np.array([
    [12,90],
    [14,80],
    [16,50]
    ])

weight = np.array([
    [10],
    [2]
])
prediction = np.dot(a, weight)
print(prediction)
# Out:
# [[300]
#  [300]
#  [260]]

# %%
# vector * vector ==  dot product
# matrix * matrix == matrix product
