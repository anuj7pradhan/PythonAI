# %%
# DHRMS
# 
# Machine learning Frameworks ---> pip
    # ML --> scilit learn framework
            # pytorch, tensorflow
                #  --> scikit learn for Prediction
                #  --> deeplearning --> pytorch, tensorflow

# %%
# Regression

    # Linear regression --> Prediction
    # mulitple

# %%
# Classification
    # Logistic Regression
    # Decision Tree
    # Random forest
    # Supprot vector machine
    # KNN
        # Naive Bayes

# %%
# Clustering
    # K-means
    # DBSCAN

# %%
# supervised learning --> we will predict in numeric
# sutdy_hrs       marks
# 1                10
# 2                20
# 3                30
# 4                40

# if his study hrs is 5 study_hrs then, how many marks he will score??

# %%
# y= mx + c
    # y --> output/label/predicted value(marks)
    # mx -->
    # c -->

# y = b + bx
    # y --> prediction
    # b0 --> starting value of y
    # bx --> change rate * input

# %%
# ex == 0,1,2,3,4
# salary == 20000,25000,30000,35000

# %%
5000 * 7 + 20000
# Out:
# 55000

# %%
age = 20
edu = 60
experience = 4  
y = m1x + m2x + m3x + ... + c
     = 20000 +  m1.20 + m2.60+ m3.4
