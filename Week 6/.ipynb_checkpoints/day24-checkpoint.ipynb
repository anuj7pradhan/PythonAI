# %%
# Machine Learning

# %%
# Traditional way
marks = 61
if marks > 60:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
# Inference
    # Training the data which is already available
# Data feedin

# %%
# Supervised learning
# Unsupervised learning

# %%
# machine will analized itself and provides predictions

# %%
# Supervised learning
    # learn from a model data 

# Types of Supervised learning

    # Regression
    # Classification
        # spam | not spam
        # pass | fail
        # boy | girl

# %%
# Unsupervised learning
    # clusterring the data into small groups

# %%
# Reinforcement learning
