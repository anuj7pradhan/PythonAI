# %%
# Box Plot
# 1. Outliers detection
# 2. Spread out
# 3. Meadian, Middle value, First half , Quartiles, Q1, Q3
# Box plot is a graph --> Distribution, center, outliers detection

# %%
import statistics

salary =[1000,2000,3000,4000,5000,6000,7000,8000]
average = statistics.mean(salary)
print(average)
# Out:
# 4500

# %%
# 0   25%     25%      25%      25%       100
# 1000,2000,3000,4000,5000,6000,7000,8000

# %%
import  matplotlib.pyplot as plt
import pandas as pd

# %%
bp1 = pd.DataFrame({
    "Employee_Name" : ["Ramesh","Amesh","Mesh","Esh","Manish","Anish","Nish","Ish"],
    "Salary": [1000,2000,3000,4000,5000,6000,7000,8000]
})
plt.boxplot(bp1["Salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1164686e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x116468980>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x116468590>],
#  'medians': [<matplotlib.lines.Line2D at 0x116468c20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x116468d70>],
#  'means': []}

# %%
import numpy as np

# %%
number = np.array([1,2,3,4,5])
print(number + 5 )
# Out:
# [ 6  7  8  9 10]
