# %%
# pip --> a package manager library
    # Used to reading, organizing, cleaning, analysing, manupulation, further preparation of data
# pandas --> panel data --> data  arrangement rows and columns

# %%
print("Hello WOrld!!!")
# Out:
# Hello WOrld!!!

# %%
countries = ["USA","Japan","Austria"]
print(countries)
print(countries[1])
print(countries.pop())
# Out:
# ['USA', 'Japan', 'Austria']
# Japan
# Austria
