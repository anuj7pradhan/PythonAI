# %% [markdown]
# # SVM (Support vector machine)

# %% [markdown]
# ## Decision Boundary
#  ### Single variable
#  wx + b = 0

# %%
import  pandas as pd

# %%
df  = pd.DataFrame({
    "StudyHours": [1,2,5,6,7],
    "Result": ['fail','fail','pass','pass','pass']
})

# %%
df
# Out:
#    StudyHours Result
# 0           1   fail
# 1           2   fail
# 2           5   pass
# 3           6   pass
# 4           7   pass
