# %%
# classification approach
# 4 Types of Classification: 
    # Binary classification, (Yes/No, 0/1, T/F)
    # Multi-Class Classification, (PoorPerformingStudent / AveragePerformingStudent / GoodPerformingStudent / ExcellencePerformingStudent)
    # Multi-label Classification ( ) and, 
    # Imbalanced Classification
import pandas as pd

# %%
df = pd.DataFrame({
    "StudyHours":[1,2,3,4,5],
    "PreviousMarks":[50,55,60,70,80],
    "Attendance":[15,12,25,10,15]
})

# %%
df
# Out:
#    StudyHours  PreviousMarks  Attendance
# 0           1             50          15
# 1           2             55          12
# 2           3             60          25
# 3           4             70          10
# 4           5             80          15
